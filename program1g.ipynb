# %%
#Sentence Tokenization
from nltk.tokenize import sent_tokenize
text = """
Hello Mr. Smith, how are you doing today? The weather is great, and city is awesome.The sky is pinkish-blue. You shouldn't eat cardboard
"""

# %%
tokenized_text = sent_tokenize(text)

# %%
print(tokenized_text)
# Out:
# ['\nHello Mr. Smith, how are you doing today?', 'The weather is great, and city is awesome.The sky is pinkish-blue.', "You shouldn't eat cardboard"]

# %%
#Word Tokenization

from nltk.tokenize import word_tokenize  
tokenized_word = word_tokenize(text)

# %%
print(tokenized_word)
# Out:
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awesome.The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard']

# %%
#Frequency Distribution 
from nltk.probability import FreqDist 
fdist  = FreqDist(tokenized_word)
print(fdist.most_common(2))
# Out:
# [('is', 3), (',', 2)]

# %%
#Frequency Distribution Plot 
import matplotlib.pyplot as plt 
fdist.plot(30 , cumulative=False)
plt.show()

# %%
#stopwords 
from nltk.corpus import stopwords 
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# {'while', 'now', 'haven', 'd', 'both', "mightn't", 'up', 'no', 'am', 'by', 'that', 'they', 'above', 'their', 'in', "shouldn't", 'these', 'theirs', 'does', 'if', 'themselves', 'but', 'who', 'when', 'most', 's', 'out', 'needn', 'her', 'are', 'we', "isn't", 'just', 'yourself', 'for', 'him', 'at', "it's", 'should', 'only', 'won', 'me', "mustn't", "hadn't", 'why', 'himself', 'all', 'whom', "didn't", 'after', 'wasn', 'be', 'hadn', 'a', 'shan', 'it', 'having', "doesn't", 'its', "don't", 'further', 'shouldn', "weren't", 'an', 'own', "you'd", "should've", 'from', 'once', 'his', 'very', 'he', "aren't", 'off', 'ourselves', 'too', 'your', 'y', 'under', 'into', 'is', 'mightn', "hasn't", 'yourselves', 'o', 'been', 'myself', 'such', "shan't", 'you', 'those', 'did', 'doesn', 'our', 'do', 'some', 'can', 'were', 'against', 'other', 'then', 'as', 'itself', 'hers', 'few', 'don', 'has', 'there', 'this', 'to', 'had', 'couldn', 'so', 'yours', 'over', 'not', 've', "you'll", 'each', 'will', 'ain', 'down', "won't", 'through', 'any', 'didn', 'm', "haven't", 'herself', 'because', 'being', 'how', 'with', 'weren', 'here', 'until', 'hasn', 'before', "needn't", 'on', "that'll", 'i', 'the', 'about', 'same', 'below', 'of', 'where', 'nor', 'was', 'have', 'll', 'my', 'doing', 'she', 'again', 't', 'wouldn', 'more', "wouldn't", "wasn't", 'what', 'them', 'or', "you're", 're', 'aren', 'isn', 'ma', 'than', 'between', 'and', 'mustn', 'ours', "couldn't", "you've", "she's", 'which', 'during'}

# %%
#Removing Stopwords 
filtered_tokens = []
for w in tokenized_word:
    if w not in stop_words:
        filtered_tokens.append(w)
print("Tokenized words:" , tokenized_word)
print("Filtered Tokens:" ,filtered_tokens)
# Out:
# Tokenized words: ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awesome.The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard']
# Filtered Tokens: ['Hello', 'Mr.', 'Smith', ',', 'today', '?', 'The', 'weather', 'great', ',', 'city', 'awesome.The', 'sky', 'pinkish-blue', '.', 'You', "n't", 'eat', 'cardboard']

# %%
import string 
punctuations = list(string.punctuation)
filtered_tokens2 = [] 
for i in filtered_tokens:
    if i not in punctuations:
        filtered_tokens2.append(i)

print("filtered Tokens After Removing Punctuations :" , filtered_tokens2)
# Out:
# filtered Tokens After Removing Punctuations : ['Hello', 'Mr.', 'Smith', 'today', 'The', 'weather', 'great', 'city', 'awesome.The', 'sky', 'pinkish-blue', 'You', "n't", 'eat', 'cardboard']
